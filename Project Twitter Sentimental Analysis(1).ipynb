# %%
# The are the dependencies which I will use
# I will create a function which will calculate the percentage,
# this fucntion will accept two arguments and return the percentages.

import re                       # "A regular expression is a special sequence of characters that helps 
import tweepy                    # you match or find other strings or sets of strings, using a specialized
from tweepy import OAuthHandler  # syntax held in a pattern.
from textblob import TextBlob     
import matplotlib.pyplot as plt


def percentage(part,whole):
    return 100 * float(part)/float(whole)

# Once I done with this I will establish the conection with our IPA

consumer_key = 'OUxRMkmiQNIp1ZrubaXMP2rvl'
consumer_secret = 'MadkHMeacd6SuqgYz80iJg3P6xc3yHoD2zJ1QLzUtwuGt3Mq7x'
access_token = '990270764673679361-GZMclvqy0Dj3ZvNESeYo22YWshQnNvo'
access_token_secret = 'VBcUwDVsAs5ERqo3qdh3K3WbVGebBBaSNxeRZWvMFbN3L'

#This line of code will take the consumer key and consumer secret which are the parameters


auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# I need to create a variable or object for our API

api = tweepy.API(auth)

# Now I can search for the terms and I can give them about how many 
# tweets I need to analyze, for that I will people and variables and second one
# will be number of tweets about this keyword/Business

searchTerm = input("Enter keyword/business to search about: ")
noOfSearchTerms = int(input("Enter how many tweets to analyze: "))

tweets = tweepy.Cursor(api.search, q = searchTerm, lang = "English").items(noOfSearchTerms)


# now the tweets contain the other bits which related to the key word(SearchTerm).

# next I use a for loop to iterate through the tweets and analyze them.

# also I will create three variables which will hold the polarity so I can calculate
# the average of positive, negative and neutral



Business_tweets = api.search("Home depot")

positive = 0
negative = 0
neutral = 0
polarity = 0

# let me create another variable call polarity to zero this will be the average result of all the tweets.

# Now

for tweet in Business_tweets:
    print(tweet.text)
    analysis = TextBlob(tweet.text)
    print(analysis.sentiment)
    
    
  # To analyze polarity is for the average sentiment of all tweets.
    polarity += analysis.sentiment.polarity
    
    # next, I add the positive, negative, and neutral polarities
    
    if(analysis.sentiment.polarity == 0):
        neutral += 1
    elif(analysis.sentiment.polarity < 0):
        negative += 1
    elif(analysis.sentiment.polarity > 0):
        positive += 1
        
        # then I create the percentages
positive = percentage(positive, noOfSearchTerms)
negative = percentage(negative, noOfSearchTerms)
neutral = percentage(neutral, noOfSearchTerms)
polarity = percentage(polarity, noOfSearchTerms)


# I need to format two  up decimal places in the code
positive = format(positive, 'f')
neutral = format(neutral, 'f')
negative = format(negative, 'f')

# Next step is to print out the result to analyze this number of tweets(noOfSearchTerms)
# and the business  to find the results

print("How people are reacting on" + searchTerm + "by analyzing" + str(noOfSearchTerms) + "Tweets.")

if (polarity == 0):
    print("Neutral")
elif (polarity < 0.00):
    print("Negative")
elif (polarity > 0.00):
    print("Positive")
    
    # Print the Pie Chart
    
labels = ['Positive ['+ str(positive) +'%]' , 'Neutral ['+ str(neutral) +'%]' , 'Negative ['+ str(negative) +'%]']
sizes = [positive, neutral, negative]
colors = ['yellowgreen', 'gold', 'red' ]
patches, texts = plt.pie(sizes, colors = colors, startangle = 90)
plt.legend(patches, labels, loc = "best")
plt.title(" How people are reacting on " + searchTerm + " by analyzing " + str(noOfSearchTerms) + " Tweets ")
plt.axis('equal')
plt.tight_layout()
plt.show()
# Out:
# Enter keyword/business to search about: "Home Depot"
# Enter how many tweets to analyze: 400
# RT @DesignationSix: The owner of Home Depot @HomeDepot loves Trump and thinks Democrats are "stupid". I have them tagged here so they will…
# Sentiment(polarity=-0.7999999999999999, subjectivity=1.0)
# @DesignationSix @HomeDepot @homeDepot Will Never Shop at Home Depot again! F*ck Trump! I’m a LOWES Girl! 😂💝👍💐
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @DesignationSix: The owner of Home Depot @HomeDepot loves Trump and thinks Democrats are "stupid". I have them tagged here so they will…
# Sentiment(polarity=-0.7999999999999999, subjectivity=1.0)
# @DesignationSix @HomeDepot That’s it won’t be buying a thing at Home Depot thanks for the information.
# Sentiment(polarity=0.2, subjectivity=0.2)
# Thankful that I have @TrueValue @AceHardware and @Lowes within 20 minutes, no need to set foot in Home Depot again. https://t.co/mNyRcc8anH
# Sentiment(polarity=0.0, subjectivity=0.0)
# ...

# %%
import re                         
import tweepy
from tweepy import OAuthHandler
from textblob import TextBlob
import matplotlib.pyplot as plt

def percentage(part,whole):
    return 100 * float(part)/float(whole)

consumer_key = 'OUxRMkmiQNIp1ZrubaXMP2rvl'
consumer_secret = 'MadkHMeacd6SuqgYz80iJg3P6xc3yHoD2zJ1QLzUtwuGt3Mq7x'
access_token = '990270764673679361-GZMclvqy0Dj3ZvNESeYo22YWshQnNvo'
access_token_secret = 'VBcUwDVsAs5ERqo3qdh3K3WbVGebBBaSNxeRZWvMFbN3L'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)



api = tweepy.API(auth)

searchTerm = input("Enter keyword/business to search about: ")
noOfSearchTerms = int(input("Enter how many tweets to analyze: "))

tweets = tweepy.Cursor(api.search, q = searchTerm, lang = "English").items(noOfSearchTerms)


business_tweets = api.search('Walmart')

positive = 0
negative = 0
neutral = 0
polarity = 0

for tweet in business_tweets:
    print(tweet.text)
    analysis = TextBlob(tweet.text)
    print(analysis.sentiment)
    
    
  # To analyze polarity is for the average sentiment of all tweets.
    polarity += analysis.sentiment.polarity
    
    # next, I add the positive, negative, and neutral polarities
    
    if(analysis.sentiment.polarity == 0):
        neutral += 1
    elif(analysis.sentiment.polarity < 0.00):
        negative += 1
    elif(analysis.sentiment.polarity > 0.00):
        positive += 1
        
        # then I create the percentages
positive = percentage(positive, noOfSearchTerms)
negative = percentage(negative, noOfSearchTerms)
neutral = percentage(neutral, noOfSearchTerms)
polarity = percentage(polarity, noOfSearchTerms)


# I need to format two  up decimal places in the code
positive = format(positive, 'f')
neutral = format(neutral, 'f')
negative = format(negative, 'f')

# Next step is to print out the result to analyze this number of tweets(noOfSearchTerms)
# and the business to find the results

print("How people are reacting on" + searchTerm + "by analyzing" + str(noOfSearchTerms) + "Tweets.")

if (polarity == 0):
    print("Neutral")
elif (polarity < 0.00):
    print("Negative")
elif (polarity > 0.00):
    print("Positive")
    
    # Print the Pie Chart
    
labels = ['Positive ['+ str(positive) +'%]' , 'Neutral ['+ str(neutral) +'%]' , 'Negative ['+ str(negative) +'%]']
sizes = [positive, neutral, negative]
colors = ['yellowgreen', 'gold', 'red' ]
patches, texts = plt.pie(sizes, colors = colors, startangle = 90)
plt.legend(patches, labels, loc = "best")
plt.title(" How people are reacting on " + searchTerm + " by analyzing " + str(noOfSearchTerms) + " Tweets ")
plt.axis('equal')
plt.tight_layout()
plt.show()
# Out:
# Enter keyword/business to search about: "Walmart"
# Enter how many tweets to analyze: 400
# RT @chandpc123: Against Illegal, Unethical &amp; Anti National deal, CAIT to CCI. @ashwani_mahajan
# @sureshpprabhu @Swamy39 @sgurumurthy @Sundar…
# Sentiment(polarity=-0.5, subjectivity=0.5)
# uhhhhh im gonna go to walmart on wednesday and see if they have love yourself
# Sentiment(polarity=0.5, subjectivity=0.6)
# @Walmart 25 minutes to wait on a Pickup in the store is too long for $9 item after I had to park &amp; hike into the st… https://t.co/e4Yd87QBWI
# Sentiment(polarity=-0.05, subjectivity=0.4)
# RT @USAHipster: Woman seen trying to escape from trunk at Virginia Walmart before men force her back in
#
# https://t.co/g0G2IWNpGr
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @FoxNews: Woman seen trying to escape from trunk at a Virginia Walmart before men force her back in. https://t.co/9D7E0cfk19
# Sentiment(polarity=0.0, subjectivity=0.0)
# ...

# %%
from textblob import TextBlob
import sys, tweepy
import matplotlib.pyplot as plt

# The are the dependencies which I will use
# I will create a function which will calculate the percentage,
# this fucntion will accept two arguments and return the percentages.

def percentage(part,whole):
    return 100 * float(part)/float(whole)

# Once I done with this I will establish the conection with our IPA


consumer_key = 'OUxRMkmiQNIp1ZrubaXMP2rvl'
consumer_secret = 'MadkHMeacd6SuqgYz80iJg3P6xc3yHoD2zJ1QLzUtwuGt3Mq7x'
access_token = '990270764673679361-GZMclvqy0Dj3ZvNESeYo22YWshQnNvo'
access_token_secret = 'VBcUwDVsAs5ERqo3qdh3K3WbVGebBBaSNxeRZWvMFbN3L'

#This line of code will take the consumer the key and consumer secret which are the parameters

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# I need to create a variable or object for our API

api = tweepy.API(auth)


# Now I can search for the terms and I can give them about how many 
# tweets I need to analyze, for that I will people and variables and second one
# will be number of tweets about this hashtag

searchTerm = input("Enter keyword/hashtag to search about: ")
noOfSearchTerms = int(input("Enter how many tweets to analyze: "))

tweets = tweepy.Cursor(api.search, q = searchTerm, lang = "English").items(noOfSearchTerms)

# now the tweets contain the other bits which related to the key word(SearchTerm).

# next I use a for loop to iterate through the tweets and analyze them.

# also I will create three variables which will hold the polarity so I can calculate
# the average of positive, negative and neutral

positive = 0
negative = 0
neutral = 0
polarity = 0

# let me create another variable call polarity to zero this will be the average result of all the tweets.

# Now
for tweet in tweets:
    print(tweet.text)
    analysis = TextBlob(tweet.text)
    
    
    # To analyze polarity is for the average sentiment of all tweets.
    polarity += analysis.sentiment.polarity
    
    # next, I add the positive, negative, and neutral polarities
    
    if(analysis.sentiment.polarity == 0):
        neutral += 1
    elif(analysis.sentiment.polarity < 0):
        negative += 1
    elif(analysis.sentiment.polarity > 0):
        positive += 1
        
        # then I create the percentages
positive = percentage(positive, noOfSearchTerms)
negative = percentage(negative, noOfSearchTerms)
neutral = percentage(neutral, noOfSearchTerms)
polarity = percentage(polarity, noOfSearchTerms)


# I need to format two  up decimal places in the code
positive = format(positive, 'f')
neutral = format(neutral, 'f')
negative = format(negative, 'f')

# Next step is to print out the result to analyze this number of tweets(noOfSearchTerms)
# and the hashtag to find the results

print("How people are reacting on" + searchTerm + "by analyzing" + str(noOfSearchTerms) + "Tweets.")

if (polarity == 0):
    print("Neutral")
elif (polarity < 0.00):
    print("Negative")
elif (polarity > 0.00):
    print("Positive")
    
    # Print the Pie Chart
    
labels = ['Positive ['+ str(positive) +'%]' , 'Neutral ['+ str(neutral) +'%]' , 'Negative ['+ str(negative) +'%]']
sizes = [positive, neutral, negative]
colors = ['yellowgreen', 'gold', 'red' ]
patches, texts = plt.pie(sizes, colors = colors, startangle = 90)
plt.legend(patches, labels, loc = "best")
plt.title(" How people are reacting on " + searchTerm + " by analyzing " + str(noOfSearchTerms) + " Tweets ")
plt.axis('equal')
plt.tight_layout()
plt.show()
# Out:
# Enter keyword/hashtag to search about: "Business"
# Enter how many tweets to analyze: 400
# When dealing #automated decision-making, people have “the right to explanation” https://t.co/5q0rAtamf4 https://t.co/5q0rAtamf4
# #NewPlymouth Taranaki #NewZealand: Health and Safety Essentials for Small Business 22 May 2018… https://t.co/Fg1SLfuBYO
# RT @JTasioulas: The UN Guiding Principles on Business &amp; Human Rights as a basis for the regulation of #AI  https://t.co/fU6VzCBlVh
# RT @JTasioulas: The UN Guiding Principles on Business &amp; Human Rights as a basis for the regulation of #AI  https://t.co/fU6VzCBlVh
# RT @JTasioulas: The UN Guiding Principles on Business &amp; Human Rights as a basis for the regulation of #AI  https://t.co/fU6VzCBlVh
# RT @JTasioulas: The UN Guiding Principles on Business &amp; Human Rights as a basis for the regulation of #AI  https://t.co/fU6VzCBlVh
# ...

# %%
# sentiment analysis is the proccess of extracting and understanding human feelings
# from data. An API lets you access the server's internal functionality like
# Twitter right from your app and the TextBlob Python library lets you perform sentiment
# analysis in just a few lines of code
